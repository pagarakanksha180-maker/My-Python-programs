# %% [markdown]
# Dictionaries:

# %%
dictionary={}  # declaration of dictionary
type(dictionary)
# Out:
# dict

# %%
state_population={"nashik":1200000,"mumbai": 1500000}
state_population['nashik']
# Out:
# 1200000

# %% [markdown]
# Updation :

# %%
state_population
# Out:
# {'nashik': 1200000, 'mumbai': 1500000}

# %%
state_population["pune"]=1300000
state_population
# Out:
# {'nashik': 1200000, 'mumbai': 1500000, 'pune': 1300000}

# %%
state_population.update({"nashik":1400000})
state_population
# Out:
# {'nashik': 1400000, 'mumbai': 1500000, 'pune': 1300000}

# %%
state_population.get("ka")

# %%
state_population.get("pune")
# Out:
# 1300000

# %%
state_population.get("pune","key not found")
# Out:
# 1300000

# %%
a=state_population.get("mumbai","key not found") # user defined message key not found
a
# Out:
# 1500000

# %%
state_population.pop("mumbai")
# Out:
# 1500000

# %%
state_population # it pops the mumbai
# Out:
# {'nashik': 1400000, 'pune': 1300000}

# %%
employee={1:"Akanksha",2:"Swamini",3:"Tanvi"}
print(employee)
# Out:
# {1: 'Akanksha', 2: 'Swamini', 3: 'Tanvi'}

# %%
for emp in employee: # key are printed
  print(emp)
# Out:
# 1
# 2
# 3

# %%
for emp in employee:  # values are printed
  print(employee[emp])
# Out:
# Akanksha
# Swamini
# Tanvi

# %%
for emp in employee:
  print(f"Employee id. {emp} is {employee[emp]}")
# Out:
# Employee id. 1 is Akanksha
# Employee id. 2 is Swamini
# Employee id. 3 is Tanvi

# %%
employee.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
employee.values()
# Out:
# dict_values(['Akanksha', 'Swamini', 'Tanvi'])

# %%
employee.items()   # both keys and values is printed
# Out:
# dict_items([(1, 'Akanksha'), (2, 'Swamini'), (3, 'Tanvi')])

# %%
for key in employee.keys():
  print(key)
# Out:
# 1
# 2
# 3

# %%
for key in employee.values():
  print(key)
# Out:
# Akanksha
# Swamini
# Tanvi

# %%
for key in employee.items():
  print(key)
# Out:
# (1, 'Akanksha')
# (2, 'Swamini')
# (3, 'Tanvi')

# %%
for emp_id,emp_name in employee.items():
  print(f"Emp_id.{emp_id} is {emp_name}")
# Out:
# Emp_id.1 is Akanksha
# Emp_id.2 is Swamini
# Emp_id.3 is Tanvi

# %% [markdown]
# Very Important
#
# 1. Values : can be duplicates or any data structure.
#
# 2. Key : it can not be contain duplicates , can't be list , dictionaries , sets as they unhashable. Tuple is hashable.

# %%
# Create a dictionary from a list of tuples.
my_list = [('name','bob'),('age','30')]
new_dict=dict(my_list)
print(new_dict)
# Out:
# {'name': 'bob', 'age': '30'}

# %% [markdown]
# Nested Dictionary

# %%
employees={"emp1":{"name":"john","salary":50000},"emp2":{"name":"Alice","salary":60000}}
print(employees["emp1"]["name"])
# Out:
# john

# %% [markdown]
# Take a string as input . Create a dictionary acc to following criteria.
#
# 1. There will be on key : value pair
#
# 2. Keys are unique character.
#
# 3. values are key's number of occurrences in string

# %%
string=input("Enter the string: ")
str_dict={}
cnt=1
for i in string:
    if i in str_dict.keys():
        str_dict[i]=cnt+1
    else:
        str_dict[i]=cnt
print(str_dict)
# Out:
# Enter the string: Akanksha
# {'A': 1, 'k': 2, 'a': 2, 'n': 1, 's': 1, 'h': 1}
